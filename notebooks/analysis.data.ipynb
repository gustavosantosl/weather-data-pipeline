# %%
path  = '../data/weather_data.json'
import pandas as pd
import json

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
with open(path) as f:
    data  =json.load(f)

df = pd.json_normlaise(data)
df.head
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 with open(path) as f:
#       2     data  =json.load(f)
#       4 df = pd.json_normlaise(data)
#
# File ~/tutorial_pipeline/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/weather_data.json'
